# %% [markdown]
# # WORKING WITH GRIB FILES
# Following the GRIB examples from the earthkit-data documentation
# https://earthkit-data.readthedocs.io/en/latest/examples/grib_overview.html

# %% [markdown]
# First, import data:

# %%
import os

cwd = os.getcwd()

print(os.listdir('../data/'))
# Out:
# ['large set', 'small set', 'vegetation types']

# %% [markdown]
# ## the datasets
#
# ### vegetation types
# we '**t**ype of **v**egetation' then '*h*igh' or '*l*ow' -- note we can find this if we do <dataset>.dump() // the name (in human readable form) will be under the properties tab

# %%
import earthkit.data as ekd

data_directory = '../data/'
data_name = 'vegetation types/data.grib'

data_path = data_directory + data_name

fs = ekd.from_source('file', data_path)

# %%
len(fs)
# Out:
# 2

# %%
fs.ls()
# Out:
#   centre shortName typeOfLevel  level  dataDate  dataTime stepRange dataType  \
# 0   ecmf       tvh     surface      0  20250702      1400         0       an
# 1   ecmf       tvl     surface      0  20250702      1400         0       an
#
#    number    gridType
# 0       0  regular_ll
# 1       0  regular_ll

# %%
fs.describe()
# Out:
# <style type="text/css">
# #T_d1d99 th {
#   text-align: left;
# }
# #T_d1d99_row0_col0, #T_d1d99_row0_col1, #T_d1d99_row0_col2, #T_d1d99_row0_col3, #T_d1d99_row0_col4, #T_d1d99_row0_col5, #T_d1d99_row0_col6, #T_d1d99_row0_col7, #T_d1d99_row0_col8, #T_d1d99_row1_col0, #T_d1d99_row1_col1, #T_d1d99_row1_col2, #T_d1d99_row1_col3, #T_d1d99_row1_col4, #T_d1d99_row1_col5, #T_d1d99_row1_col6, #T_d1d99_row1_col7, #T_d1d99_row1_col8 {
#   text-align: left;
# }
# </style>
# <table id="T_d1d99">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1d99_level0_col0" class="col_heading level0 col0" >level</th>
#       <th id="T_d1d99_level0_col1" class="col_heading level0 col1" >date</th>
#       <th id="T_d1d99_level0_col2" class="col_heading level0 col2" >time</th>
#       <th id="T_d1d99_level0_col3" class="col_heading level0 col3" >step</th>
#       <th id="T_d1d99_level0_col4" class="col_heading level0 col4" >paramId</th>
#       <th id="T_d1d99_level0_col5" class="col_heading level0 col5" >class</th>
#       <th id="T_d1d99_level0_col6" class="col_heading level0 col6" >stream</th>
#       <th id="T_d1d99_level0_col7" class="col_heading level0 col7" >type</th>
#       <th id="T_d1d99_level0_col8" class="col_heading level0 col8" >experimentVersionNumber</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >shortName</th>
#       <th class="index_name level1" >typeOfLevel</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1d99_level0_row0" class="row_heading level0 row0" >tvh</th>
#       <th id="T_d1d99_level1_row0" class="row_heading level1 row0" >surface</th>
#       <td id="T_d1d99_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d1d99_row0_col1" class="data row0 col1" >20250702</td>
#       <td id="T_d1d99_row0_col2" class="data row0 col2" >1400</td>
#       <td id="T_d1d99_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d1d99_row0_col4" class="data row0 col4" >30</td>
#       <td id="T_d1d99_row0_col5" class="data row0 col5" >ea</td>
#       <td id="T_d1d99_row0_col6" class="data row0 col6" >oper</td>
#       <td id="T_d1d99_row0_col7" class="data row0 col7" >an</td>
#       <td id="T_d1d99_row0_col8" class="data row0 col8" >0005</td>
#     </tr>
#     <tr>
#       <th id="T_d1d99_level0_row1" class="row_heading level0 row1" >tvl</th>
#       <th id="T_d1d99_level1_row1" class="row_heading level1 row1" >surface</th>
#       <td id="T_d1d99_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d1d99_row1_col1" class="data row1 col1" >20250702</td>
#       <td id="T_d1d99_row1_col2" class="data row1 col2" >1400</td>
#       <td id="T_d1d99_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_d1d99_row1_col4" class="data row1 col4" >29</td>
#       <td id="T_d1d99_row1_col5" class="data row1 col5" >ea</td>
#       <td id="T_d1d99_row1_col6" class="data row1 col6" >oper</td>
#       <td id="T_d1d99_row1_col7" class="data row1 col7" >an</td>
#       <td id="T_d1d99_row1_col8" class="data row1 col8" >0005</td>
#     </tr>
#   </tbody>
# </table>

# %%
tvh = fs[0]
tvl = fs[1]

# %%
xa_tvh = tvh.to_xarray()

xa_tvh
# Out:
# <xarray.Dataset> Size: 8MB
# Dimensions:    (latitude: 721, longitude: 1440)
# Coordinates:
#   * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
# Data variables:
#     tvh        (latitude, longitude) float64 8MB ...
# Attributes: (12/13)
#     param:        tvh
#     paramId:      30
#     class:        ea
#     stream:       oper
#     levtype:      sfc
#     type:         an
#     ...           ...
#     date:         20250702
#     time:         1400
#     domain:       g
#     number:       0
#     Conventions:  CF-1.8
#     institution:  ECMWF

# %%
tvl.dump()
# Out:
# {'default': {'globalDomain': 'g',
#   'GRIBEditionNumber': 1,
#   'eps': 0,
#   'offsetSection0': 0,
#   'section0Length': 8,
#   'totalLength': 2076588,
#   'editionNumber': 1,
#   'WMO': 0,
#   'productionStatusOfProcessedData': 0,
#   'section1Length': 52,
#   'table2Version': 128,
#   'centre': 'ecmf',
#   'centreDescription': 'European Centre for Medium-Range Weather Forecasts',
#   'generatingProcessIdentifier': 145,
#   'gridDefinition': 255,
#   'indicatorOfParameter': 29,
#   'parameterName': 'Type of low vegetation',
#   'parameterUnits': '~',
#   'indicatorOfTypeOfLevel': 'sfc',
#   'pressureUnits': 'hPa',
#   'typeOfLevelECMF': 'surface',
#   'typeOfLevel': 'surface',
#   'level': 0,
#   'yearOfCentury': 25,
#   'month': 7,
#   'day': 2,
#   'hour': 14,
#   'minute': 0,
#   'second': 0,
#   'unitOfTimeRange': 1,
#   'P1': 0,
#   'P2': 0,
#   'timeRangeIndicator': 0,
#   'numberIncludedInAverage': 0,
#   'numberMissingFromAveragesOrAccumulations': 0,
#   'centuryOfReferenceTimeOfData': 21,
#   'subCentre': 0,
#   'paramIdECMF': '29',
#   'paramId': 29,
#   'cfNameECMF': 'unknown',
#   'cfName': 'unknown',
#   'unitsECMF': '(Code table 4.234)',
#   'units': '(Code table 4.234)',
#   'nameECMF': 'Type of low vegetation',
#   'name': 'Type of low vegetation',
#   'decimalScaleFactor': 0,
#   'setLocalDefinition': 0,
#   'optimizeScaleFactor': 0,
#   'dataDate': 20250702,
#   'year': 2025,
#   'dataTime': 1400,
#   'julianDay': 2460859.0833333335,
#   'stepUnits': 1,
#   'stepType': 'instant',
#   'stepRange': '0',
#   'startStep': 0,
#   'endStep': 0,
#   'marsParam': '29.128',
#   'validityDate': 20250702,
#   'validityTime': 1400,
#   'validityDateTime': 2460858.509722222,
#   'deleteLocalDefinition': 0,
#   'localUsePresent': 1,
#   'reservedNeedNotBePresent': [''],
#   'localDefinitionNumber': 1,
#   'GRIBEXSection1Problem': 0,
#   'marsClass': 'ea',
#   'marsType': 'an',
#   'marsStream': 'oper',
#   'experimentVersionNumber': '0005',
#   'perturbationNumber': 0,
#   'numberOfForecastsInEnsemble': 0,
#   'padding_local1_1': '00',
#   'grib2LocalSectionNumber': 1,
#   'localExtensionPadding': '',
#   '_x': None,
#   'section1Padding': '',
#   'shortNameECMF': 'tvl',
#   'shortName': 'tvl',
#   'cfVarNameECMF': 'tvl',
#   'cfVarName': 'tvl',
#   'stepTypeForConversion': 'unknown',
#   'md5Section1': '99b53da0eccacc64e8ae3ec57709f277',
#   'md5Product': '444d4e47513482333efde8616300b2e6',
#   'paramIdForConversion': 0,
#   'gridDescriptionSectionPresent': 1,
#   'bitmapPresent': 0,
#   'angleSubdivisions': 1000,
#   'section2Length': 32,
#   'radius': 6367470,
#   'numberOfVerticalCoordinateValues': 0,
#   'neitherPresent': 255,
#   'pvlLocation': 255,
#   'dataRepresentationType': 0,
#   'gridDefinitionDescription': 'Latitude/Longitude Grid',
#   'gridDefinitionTemplateNumber': 0,
#   'Ni': 1440,
#   'Nj': 721,
#   'latitudeOfFirstGridPoint': 90000,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPoint': 0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'resolutionAndComponentFlags': 128,
#   'ijDirectionIncrementGiven': 1,
#   'earthIsOblate': 0,
#   'resolutionAndComponentFlags3': 0,
#   'resolutionAndComponentFlags4': 0,
#   'uvRelativeToGrid': 0,
#   'resolutionAndComponentFlags6': 0,
#   'resolutionAndComponentFlags7': 0,
#   'resolutionAndComponentFlags8': 0,
#   'latitudeOfLastGridPoint': -90000,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPoint': 359750,
#   'longitudeOfLastGridPointInDegrees': 359.75,
#   'iDirectionIncrement': 250,
#   'jDirectionIncrement': 250,
#   'isGridded': 1,
#   'scanningMode': 0,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'alternativeRowScanning': 0,
#   'iScansPositively': 1,
#   'jScansNegatively': 1,
#   'scanningMode4': 0,
#   'scanningMode5': 0,
#   'scanningMode6': 0,
#   'scanningMode7': 0,
#   'scanningMode8': 0,
#   'swapScanningAlternativeRows': 0,
#   'jDirectionIncrementInDegrees': 0.25,
#   'iDirectionIncrementInDegrees': 0.25,
#   'numberOfDataPoints': 1038240,
#   'numberOfValues': 1038240,
#   'zeros': '',
#   'PVPresent': 0,
#   'padding_sec2_2': '',
#   'PLPresent': 0,
#   'padding_sec2_1': '',
#   'deletePV': '1',
#   'padding_sec2_3': '',
#   'md5Section2': 'de9ac28d23b2d4d93c4a744a90739f15',
#   'isSpectral': 0,
#   'lengthOfHeaders': 85,
#   'md5Headers': 'd1cb703f4decb99643129cb01e2213ff',
#   'isMessageValid': 1,
#   'missingValue': 9999,
#   'tableReference': 0,
#   'section4Length': 2076492,
#   'halfByte': 8,
#   'dataFlag': 8,
#   'binaryScaleFactor': -11,
#   'referenceValue': 0.0,
#   'referenceValueError': 5.397605346934028e-79,
#   'sphericalHarmonics': 0,
#   'complexPacking': 0,
#   'integerPointValues': 0,
#   'additionalFlagPresent': 0,
#   'orderOfSPD': 2,
#   'boustrophedonic': 0,
#   'packingType': 'grid_simple',
#   'bitsPerValue': 16,
#   'constantFieldHalfByte': 8,
#   'bitMapIndicator': 255,
#   'numberOfCodedValues': 1038240,
#   'packingError': 0.000244140625,
#   'unpackedError': 1.1754943508222875e-38,
#   'maximum': 17.0,
#   'minimum': 0.0,
#   'average': 1.4070253505933117,
#   'standardDeviation': 3.574258897374277,
#   'skewness': 2.635566691195576,
#   'kurtosis': 6.051036712168273,
#   'isConstant': 0.0,
#   'numberOfMissing': 0,
#   'dataLength': 259560,
#   'changeDecimalPrecision': 0,
#   'decimalPrecision': 0,
#   'bitsPerValueAndRepack': 16,
#   'setPackingType': 'grid_simple',
#   'scaleValuesBy': 1.0,
#   'offsetValuesBy': 0.0,
#   'gridType': 'regular_ll',
#   'getNumberOfValues': 1038240,
#   'padding_sec4_1': '',
#   'md5Section4': '778a2cba42aaa8a5bc42042501a98aaf',
#   'section5Length': 4,
#   '7777': '7777'},
#  'ls': {'edition': 1,
#   'centre': 'ecmf',
#   'typeOfLevel': 'surface',
#   'level': 0,
#   'dataDate': 20250702,
#   'stepRange': '0',
#   'dataType': 'an',
#   'shortName': 'tvl',
#   'packingType': 'grid_simple',
#   'gridType': 'regular_ll'},
#  'geography': {'Ni': 1440,
#   'Nj': 721,
#   'latitudeOfFirstGridPointInDegrees': 90.0,
#   'longitudeOfFirstGridPointInDegrees': 0.0,
#   'latitudeOfLastGridPointInDegrees': -90.0,
#   'longitudeOfLastGridPointInDegrees': 359.75,
#   'iScansNegatively': 0,
#   'jScansPositively': 0,
#   'jPointsAreConsecutive': 0,
#   'jDirectionIncrementInDegrees': 0.25,
#   'iDirectionIncrementInDegrees': 0.25,
#   'gridType': 'regular_ll'},
#  'mars': {'domain': 'g',
#   'levtype': 'sfc',
#   'date': 20250702,
#   'time': 1400,
#   'step': 0,
#   'param': 'tvl',
#   'class': 'ea',
#   'type': 'an',
#   'stream': 'oper',
#   'expver': '0005'},
#  'parameter': {'centre': 'ecmf',
#   'paramId': 29,
#   'units': '(Code table 4.234)',
#   'name': 'Type of low vegetation',
#   'shortName': 'tvl'},
#  'statistics': {'max': 17.0,
#   'min': 0.0,
#   'avg': 1.4070253505933117,
#   'sd': 3.574258897374277,
#   'skew': 2.635566691195576,
#   'kurt': 6.051036712168273,
#   'const': 0.0},
#  'time': {'dataDate': 20250702,
#   'dataTime': 1400,
#   'stepUnits': 1,
#   'stepType': 'instant',
#   'stepRange': '0',
#   'startStep': 0,
#   'endStep': 0,
#   'validityDate': 20250702,
#   'validityTime': 1400},
#  'vertical': {'typeOfLevel': 'surface', 'level': 0}}
